# %%
# The modules below are required
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt

# %%
# Import the race module
import race

# %% [markdown]
# ## Run a single trial

# %%
# Run help(race.act_single) for more information
act_single = race.single_race([0.05, 0.045, 0.04], 0.02)
print(act_single)
# Out:
# [[0.1        0.1        0.1       ]
#  [0.1579432  0.12110832 0.1675751 ]
#  [0.19434654 0.13607592 0.19699824]
#  [0.21701488 0.22950728 0.25029079]
#  [0.27029283 0.25889588 0.28646569]
#  [0.31931782 0.29055729 0.32829409]
#  [0.35341315 0.33987658 0.34667007]
#  [0.36394304 0.3577641  0.37633708]
#  [0.38755679 0.40135123 0.42066816]
#  [0.41152696 0.43236255 0.44421849]
#  [0.42899951 0.47281343 0.47424734]
#  [0.45012542 0.46509605 0.46792181]
#  [0.44889341 0.46792426 0.46545195]
#  [0.46722935 0.48347952 0.49933508]
#  [0.46689107 0.47292828 0.48839254]
#  [0.44023568 0.46731727 0.47889644]
#  [0.43263676 0.47592813 0.47785   ]
#  [0.4304864  0.46973882 0.48635143]
#  [0.42593797 0.47436855 0.48345279]
#  [0.41729344 0.48212552 0.48411749]
#  [0.39898758 0.50382788 0.47106295]
#  [0.3757084  0.50468748 0.45341051]
#  [0.37235263 0.52768052 0.43803108]
#  [0.34829157 0.53304135 0.42584647]
#  [0.33761922 0.54099942 0.40230566]
#  [0.32806218 0.5525686  0.38309288]
#  [0.31415967 0.57225425 0.35992448]
#  [0.29010605 0.59669754 0.3311293 ]
#  [0.27325364 0.619532   0.30029404]
#  [0.25726139 0.63134723 0.27316368]
#  [0.24130244 0.65514754 0.24202721]
#  [0.22445218 0.67515182 0.22862022]
#  [0.20329983 0.70324401 0.21070217]]

# %%
# You can easily plot the activation using matplotlib (or seaborn or whatever way)
plt.plot(act_single)
# Out:
# [<matplotlib.lines.Line2D at 0x7fcf866a3668>,
#  <matplotlib.lines.Line2D at 0x7fcf866b2240>,
#  <matplotlib.lines.Line2D at 0x7fcf866b22e8>]

# %%
# The same thing can be done with race function
# But be careful that the output activation matrix has more dimensions
act_single_2 = race.race(np.array([0.05, 0.045, 0.04]), 0.02, 1, max_cycle = 25)
print(act_single_2)
plt.plot(act_single_2[0,0])
# Out:
# [[[[0.1        0.1        0.1       ]
#    [0.15087913 0.13106428 0.13600193]
#    [0.22620675 0.15848611 0.16527041]
#    [0.25996855 0.21273428 0.19963835]
#    [0.29912953 0.26523801 0.22718545]
#    [0.3138782  0.31024608 0.258928  ]
#    [0.37892294 0.33423401 0.27819059]
#    [0.41229848 0.3601445  0.33751682]
#    [0.439022   0.38035701 0.36640505]
#    [0.48608817 0.41145483 0.37238171]
#    [0.49894182 0.41581335 0.3662796 ]
#    [0.5061565  0.4263105  0.37636198]
#    [0.54409737 0.41716394 0.36808507]
#    [0.57235311 0.38643766 0.34536516]
#    [0.59927996 0.36753396 0.31801876]
#    [0.62298638 0.33712304 0.29127339]
#    [0.64015217 0.31656207 0.27228369]
#    [0.65462684 0.2968288  0.24474402]
#    [0.67562904 0.27699756 0.22484952]
#    [0.69296662 0.24989197 0.20074197]
#    [0.71111201 0.2277359  0.17830944]
#    [0.7346658  0.20316993 0.16321987]
#    [0.75684645 0.18590564 0.14340859]
#    [0.78016856 0.15897627 0.12409629]
#    [0.79425778 0.14163936 0.10959787]
#    [0.79823293 0.12777466 0.10055948]]]]
# [<matplotlib.lines.Line2D at 0x7fcf8678c390>,
#  <matplotlib.lines.Line2D at 0x7fcf8678c400>,
#  <matplotlib.lines.Line2D at 0x7fcf8678c4a8>]

# %% [markdown]
# ## Simulate multiple trials in one context

# %%
# Simulate a single context with multiple participants
# The third function specifies the number of races
# See help(race.race) for more information
ac = race.race(np.array([0.05, 0.045, 0.04]), 0.02, 40)

# %%
# Average across trials for each cycle
ac_average = np.mean(ac, axis = 1) # This means that average across axis 1 (i.e. trials)
# Print average activation in each cycle
plt.plot(ac_average[0])
# Print average activation at 32nd cycle
print(ac_average[0, 32,:])
# Out:
# [0.6064896  0.25724027 0.1074295 ]

# %%
# Summarize the results
df0, df1 = race.act2df(ac, 0.7)

# %%
# Each trial
df0
# Out:
#     context_id  response  ft  rt_25  cloze_prob  modal_prob
# 0            0         1  30   1100        0.25         0.7
# 1            0         0  25    975        0.70         0.7
# 2            0         0  22    900        0.70         0.7
# 3            0         0  30   1100        0.70         0.7
# 4            0         1  25    975        0.25         0.7
# 5            0         0  26   1000        0.70         0.7
# 6            0         0  21    875        0.70         0.7
# 7            0         0  28   1050        0.70         0.7
# 8            0         1  33   1175        0.25         0.7
# 9            0         1  29   1075        0.25         0.7
# 10           0         0  24    950        0.70         0.7
# 11           0         0  20    850        0.70         0.7
# 12           0         0  24    950        0.70         0.7
# 13           0         1  25    975        0.25         0.7
# 14           0         1  22    900        0.25         0.7
# 15           0         1  27   1025        0.25         0.7
# 16           0         0  21    875        0.70         0.7
# 17           0         2  30   1100        0.05         0.7
# 18           0         0  26   1000        0.70         0.7
# 19           0         1  28   1050        0.25         0.7
# 20           0         0  25    975        0.70         0.7
# 21           0         1  24    950        0.25         0.7
# 22           0         0  23    925        0.70         0.7
# 23           0         0  22    900        0.70         0.7
# 24           0         0  26   1000        0.70         0.7
# 25           0         0  23    925        0.70         0.7
# 26           0         0  23    925        0.70         0.7
# 27           0         0  26   1000        0.70         0.7
# 28           0         0  23    925        0.70         0.7
# 29           0         2  29   1075        0.05         0.7
# 30           0         0  24    950        0.70         0.7
# 31           0         0  20    850        0.70         0.7
# 32           0         0  25    975        0.70         0.7
# 33           0         0  20    850        0.70         0.7
# 34           0         0  29   1075        0.70         0.7
# 35           0         0  21    875        0.70         0.7
# 36           0         0  24    950        0.70         0.7
# 37           0         1  26   1000        0.25         0.7
# 38           0         0  26   1000        0.70         0.7
# 39           0         0  23    925        0.70         0.7

# %%
# Each competitor
df1
# Out:
#    context_id  response         ft        rt_25  total_count  count  \
# 0           0         0  23.928571   948.214286           40     28
# 1           0         1  26.900000  1022.500000           40     10
# 2           0         2  29.500000  1087.500000           40      2
#
#    cloze_prob  modal_prob
# 0        0.70         0.7
# 1        0.25         0.7
# 2        0.05         0.7

# %% [markdown]
# ## Simulate multiple trials in multiple contexts

# %%
# Set mu parameters for two contexts
mu_mult = np.array([[0.05, 0.045, 0.04], [0.05, 0.04, 0.035]])
mu_mult
# Out:
# array([[0.05 , 0.045, 0.04 ],
#        [0.05 , 0.04 , 0.035]])

# %%
# Just give 2-dimension mus to run multipe contexts
ac_m = race.race(mu_mult, 0.02, 40)

# %%
# Average across trials
ac_average_m = np.mean(ac_m, axis = 1)

# %%
# Plot the first context (with stronger competitors)
plt.plot(ac_average_m[0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fcf8683ba90>,
#  <matplotlib.lines.Line2D at 0x7fcf8683bb38>,
#  <matplotlib.lines.Line2D at 0x7fcf8683bbe0>]

# %%
# Plot the second context (with waker competitors)
plt.plot(ac_average_m[1])
# Out:
# [<matplotlib.lines.Line2D at 0x7fcf86a8ee10>,
#  <matplotlib.lines.Line2D at 0x7fcf86a8eeb8>,
#  <matplotlib.lines.Line2D at 0x7fcf86a8ef60>]

# %%
# Summarize the data
df0_m, df1_m = race.act2df(ac_m, 0.7)

# %%
df1_m
# Out:
#    context_id  response         ft        rt_25  total_count  count  \
# 0           0         0  22.096774   902.419355           40     31
# 1           0         1  26.888889  1022.222222           40      9
# 2           1         0  22.181818   904.545455           40     33
# 3           1         1  24.500000   962.500000           40      4
# 4           1         2  28.333333  1058.333333           40      3
#
#    cloze_prob  modal_prob
# 0       0.775       0.775
# 1       0.225       0.775
# 2       0.825       0.825
# 3       0.100       0.825
# 4       0.075       0.825

# %% [markdown]
# ## Randomly generate multiple contexts

# %% [markdown]
# To simulate 10 participants, generating mu parameters from a normal distribution with $\mu = 0.02, \sigma = 0.01$ seem to resemble Staub et al. (2015)'s experimental data.
# Similarly for `race_fast` (or `race`), setting the sigma parameter to 0.03 and the rate parameter to 0.2 (which is the default) seem to work well.

# %%
# Randomly generate competitors in 500 contexts
m_mat = np.random.normal(0, 0.01, [500, 10]) + 0.02

# %%
# Sort the matrix so that competitor 0 is always the strongest in each context
m_mat.sort(axis = 1)
m_mat = m_mat[:, ::-1]

# %%
# This is basically the same as race.race + race.act2df, but runs faster without outputting the activation patterns
df0_10_500, df1_10_500  = race.race_fast(m_mat, 0.03, 40)
# Out:
# ■■■■■■■■■■ : 500/500

# %%
df1_10_500
# Out:
#       context_id  response         ft        rt_25  total_count  count  \
# 0              0         0  25.148148   978.703704           40     27
# 1              0         1  27.444444  1036.111111           40      9
# 2              0         2  36.000000  1250.000000           40      1
# 3              0         3  45.000000  1475.000000           40      1
# 4              0         4  34.500000  1212.500000           40      2
# ...          ...       ...        ...          ...          ...    ...
# 2493         499         0  29.750000  1093.750000           40     20
# 2494         499         1  31.333333  1133.333333           40      9
# 2495         499         2  31.444444  1136.111111           40      9
# 2496         499         4  32.000000  1150.000000           40      1
# 2497         499         5  43.000000  1425.000000           40      1
#
#       cloze_prob  modal_prob
# 0          0.675       0.675
# 1          0.225       0.675
# 2          0.025       0.675
# 3          0.025       0.675
# 4          0.050       0.675
# ...          ...         ...
# 2493       0.500       0.500
# 2494       0.225       0.500
# 2495       0.225       0.500
# 2496       0.025       0.500
# 2497       0.025       0.500
#
# [2498 rows x 8 columns]

# %%
df0_10_500
# Out:
#        context_id  response  ft  rt_25  cloze_prob  modal_prob
# 0               0         3  45   1475       0.025       0.675
# 1               0         0  24    950       0.675       0.675
# 2               0         0  20    850       0.675       0.675
# 3               0         0  25    975       0.675       0.675
# 4               0         1  27   1025       0.225       0.675
# ...           ...       ...  ..    ...         ...         ...
# 19995         499         0  34   1200       0.500       0.500
# 19996         499         0  29   1075       0.500       0.500
# 19997         499         0  24    950       0.500       0.500
# 19998         499         2  29   1075       0.225       0.500
# 19999         499         2  30   1100       0.225       0.500
#
# [20000 rows x 6 columns]

# %%
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(8,6)})

# %%
# Check the rt - probability correlation
sns.pointplot(data = df0_10_500, x = "cloze_prob", y = "rt_25", linestyles='')
# Out:
# <AxesSubplot:xlabel='cloze_prob', ylabel='rt_25'>

# %% [markdown]
# ## An example elaboration

# %% [markdown]
# ### Just look at races where specific competitors won

# %%
def single_context_activation_winner(mu, sigma, nrace, winner, max_cycle = 100, threshold = 0.7, init = 0.1, rate = 0.2, sigmoid = True, beta = 35, x_zero = 0.5, cm = True, decay = 0):
    
    actmat_all = np.zeros([nrace, max_cycle + 1, len(mu)])
    
    i = 0
    while i < nrace:
        # Get the activation for one context
        temp_actmat = race.single_race(mu, sigma, max_cycle = max_cycle, threshold = 100, init = init, rate = rate, sigmoid = sigmoid, beta = beta, x_zero = x_zero, cm = cm, decay = decay)     
        if np.argmax(temp_actmat[-1]) == winner:
            actmat_all[i] = temp_actmat
            i = i + 1
        
    return actmat_all

# %% [markdown]
# Compare acitvation **when the competitor wins the race**

# %%
# Get hundred wins by each candidate
a0 = single_context_activation_winner([0.05, 0.045, 0.04], 0.02, 100, 0, cm = True)
a1 = single_context_activation_winner([0.05, 0.045, 0.04], 0.02, 100, 1, cm = True)
a2 = single_context_activation_winner([0.05, 0.045, 0.04], 0.02, 100, 2, cm = True)
# Extract the cases where each competitor wins
winners_array = np.stack((np.mean(a0, axis = 0)[:, 0], np.mean(a1, axis = 0)[:, 1], np.mean(a2, axis = 0)[:, 2]), axis = 1)
plt.plot(winners_array)

# %%
# Set smaller inhibition rate
irate = 0.05
# Get hundred wins by each candidate
a0 = single_context_activation_winner([0.05, 0.045, 0.04], 0.02, 20, 0, rate = irate, cm = True)
a1 = single_context_activation_winner([0.05, 0.045, 0.04], 0.02, 20, 1, rate = irate, cm = True)
a2 = single_context_activation_winner([0.05, 0.045, 0.04], 0.02, 20, 2, rate = irate, cm = True)
winners_array = np.stack((np.mean(a0, axis = 0)[:, 0], np.mean(a1, axis = 0)[:, 1], np.mean(a2, axis = 0)[:, 2]), axis = 1)
plt.plot(winners_array)
